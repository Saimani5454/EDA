# %% [markdown]
# <a href="https://colab.research.google.com/github/Saimani5454/EDA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('data_clean.csv')
df1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
df1.shape
# Out:
# (158, 10)

# %%
df1.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df2=df1.iloc[:,1:]
df2
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df2=df1.copy()
df2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df2["Temp C"]=pd.to_numeric(df2["Temp C"],errors='coerce')
df2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    67.0     5    1  2010    67       S
# 1             2   36.0    118.0   8.0    72.0     5    2  2010    72       C
# 2             3   12.0    149.0  12.6    74.0     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0     5    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0     5    5  2010    56       S
# ..          ...    ...      ...   ...     ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0     5    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0     9   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0     9   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 12.5+ KB
# None

# %%
df2['Weather']=df2['Weather'].astype('category')
df2['Wind']=df2['Wind'].astype('category')
df2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    67.0     5    1  2010    67       S
# 1             2   36.0    118.0   8.0    72.0     5    2  2010    72       C
# 2             3   12.0    149.0  12.6    74.0     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0     5    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0     5    5  2010    56       S
# ..          ...    ...      ...   ...     ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0     5    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0     9   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0     9   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
df2[df2.duplicated()].shape
# Out:
# (0, 10)

# %%
data_clean=df2.drop_duplicates()
data_clean
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    67.0     5    1  2010    67       S
# 1             2   36.0    118.0   8.0    72.0     5    2  2010    72       C
# 2             3   12.0    149.0  12.6    74.0     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0     5    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0     5    5  2010    56       S
# ..          ...    ...      ...   ...     ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0     5    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0     9   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0     9   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df1=data_clean.copy()
df1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    67.0     5    1  2010    67       S
# 1             2   36.0    118.0   8.0    72.0     5    2  2010    72       C
# 2             3   12.0    149.0  12.6    74.0     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0     5    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0     5    5  2010    56       S
# ..          ...    ...      ...   ...     ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0     5    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0     9   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0     9   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# df1
# rows=None
# pd.set_option('display.max_rows',rows)

# %%
data_clean.shape
# Out:
# (158, 10)

# %%
data_cleaned1=data_clean.drop('Temp C',axis=1)
data_cleaned1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     5    5  2010    56       S
# ..          ...    ...      ...   ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data_cleaned2=data_cleaned1.rename({'Solar.R':'Solar'},axis=1)
data_cleaned2
data_cleaned2['Ozone'].hist()
# Out:
# <Axes: >

# %%
data_cleaned2.boxplot(column=['Ozone'])
# Out:
# <Axes: >

# %%
data_cleaned2['Ozone'].describe()
# Out:
# count    120.000000
# mean      41.583333
# std       32.620709
# min        1.000000
# 25%       18.000000
# 50%       30.500000
# 75%       61.500000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
df1['Month'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Month'>

# %%
cols=data_cleaned2.columns
colours=['#000099','#ffff00']
sns.heatmap(data_cleaned2[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
data_cleaned2[data_cleaned2.isnull().any(axis=1)].head()
# Out:
#     Unnamed: 0  Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 4            5    NaN    NaN  14.3     5    5  2010    56       S
# 5            6   28.0    NaN  14.9     5    6  2010    66       C
# 9           10    NaN  194.0   8.6     5   10  2010    69       S
# 10          11    7.0    NaN   6.9     5   11  2010    74       C
# 24          25    NaN   66.0  16.6     5   25  2010    57      PS

# %%
data_cleaned2.isnull().sum(

)
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
mean=data_cleaned2['Ozone'].mean()
print(mean)
# Out:
# 41.583333333333336

# %%
data_cleaned2['Ozone']=data_cleaned2['Ozone'].fillna(mean)

# %%
data_cleaned2['Ozone'].isnull().sum()
# Out:
# 0

# %%
data_cleaned2['Ozone']
# Out:
# 0      41.000000
# 1      36.000000
# 2      12.000000
# 3      18.000000
# 4      41.583333
#          ...
# 153    41.000000
# 154    30.000000
# 155    41.583333
# 156    14.000000
# 157    18.000000
# Name: Ozone, Length: 158, dtype: float64

# %%
obj_columns=data_cleaned2[['Weather']]

# %%
obj_columns.value_counts()
# Out:
# Weather
# S          59
# C          49
# PS         47
# Name: count, dtype: int64

# %%
obj_columns=obj_columns.fillna(obj_columns.mode().iloc[0])

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned2['Solar']=data_cleaned2['Solar'].fillna(data_cleaned2['Solar'].mean())

# %%
data_cleaned2=data_cleaned2.drop('Weather',axis=1)
data_cleaned2
# Out:
#      Unnamed: 0      Ozone       Solar  Wind Month  Day  Year  Temp
# 0             1  41.000000  190.000000   7.4     5    1  2010    67
# 1             2  36.000000  118.000000   8.0     5    2  2010    72
# 2             3  12.000000  149.000000  12.6     5    3  2010    74
# 3             4  18.000000  313.000000  11.5     5    4  2010    62
# 4             5  41.583333  185.403974  14.3     5    5  2010    56
# ..          ...        ...         ...   ...   ...  ...   ...   ...
# 153         154  41.000000  190.000000   7.4     5    1  2010    67
# 154         155  30.000000  193.000000   6.9     9   26  2010    70
# 155         156  41.583333  145.000000  13.2     9   27  2010    77
# 156         157  14.000000  191.000000  14.3     9   28  2010    75
# 157         158  18.000000  131.000000   8.0     9   29  2010    76
#
# [158 rows x 8 columns]

# %%
data_cleaned2
# Out:
#      Unnamed: 0      Ozone       Solar  Wind Month  Day  Year  Temp
# 0             1  41.000000  190.000000   7.4     5    1  2010    67
# 1             2  36.000000  118.000000   8.0     5    2  2010    72
# 2             3  12.000000  149.000000  12.6     5    3  2010    74
# 3             4  18.000000  313.000000  11.5     5    4  2010    62
# 4             5  41.583333  185.403974  14.3     5    5  2010    56
# ..          ...        ...         ...   ...   ...  ...   ...   ...
# 153         154  41.000000  190.000000   7.4     5    1  2010    67
# 154         155  30.000000  193.000000   6.9     9   26  2010    70
# 155         156  41.583333  145.000000  13.2     9   27  2010    77
# 156         157  14.000000  191.000000  14.3     9   28  2010    75
# 157         158  18.000000  131.000000   8.0     9   29  2010    76
#
# [158 rows x 8 columns]

# %%
data_cleaned2=pd.concat([data_cleaned2,obj_columns],axis=1)
data_cleaned2.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         0
# Wind          0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       0
# dtype: int64

# %%
sns.pairplot(data_cleaned2.iloc[:,0:7])

# %%
data_cleaned2
data_cleaned2['Month']=data_cleaned2['Month'].replace(['May'],'5')
data_cleaned2.iloc[:,0:6].corr()
data_cleaned2.dtypes
# Out:
# Unnamed: 0       int64
# Ozone          float64
# Solar          float64
# Wind          category
# Month           object
# Day              int64
# Year             int64
# Temp             int64
# Weather       category
# dtype: object

# %%
data_cleaned3=pd.get_dummies(data_cleaned2,columns=['Weather'],dtype=int)
data_cleaned3
# Out:
#      Unnamed: 0      Ozone       Solar  Wind Month  Day  Year  Temp  \
# 0             1  41.000000  190.000000   7.4     5    1  2010    67
# 1             2  36.000000  118.000000   8.0     5    2  2010    72
# 2             3  12.000000  149.000000  12.6     5    3  2010    74
# 3             4  18.000000  313.000000  11.5     5    4  2010    62
# 4             5  41.583333  185.403974  14.3     5    5  2010    56
# ..          ...        ...         ...   ...   ...  ...   ...   ...
# 153         154  41.000000  190.000000   7.4     5    1  2010    67
# 154         155  30.000000  193.000000   6.9     9   26  2010    70
# 155         156  41.583333  145.000000  13.2     9   27  2010    77
# 156         157  14.000000  191.000000  14.3     9   28  2010    75
# 157         158  18.000000  131.000000   8.0     9   29  2010    76
#
#      Weather_C  Weather_PS  Weather_S
# 0            0           0          1
# 1            1           0          0
# ...

# %%
data_cleaned3=data_cleaned3.dropna()
data_cleaned3
# Out:
#      Unnamed: 0      Ozone       Solar  Wind Month  Day  Year  Temp  \
# 0             1  41.000000  190.000000   7.4     5    1  2010    67
# 1             2  36.000000  118.000000   8.0     5    2  2010    72
# 2             3  12.000000  149.000000  12.6     5    3  2010    74
# 3             4  18.000000  313.000000  11.5     5    4  2010    62
# 4             5  41.583333  185.403974  14.3     5    5  2010    56
# ..          ...        ...         ...   ...   ...  ...   ...   ...
# 153         154  41.000000  190.000000   7.4     5    1  2010    67
# 154         155  30.000000  193.000000   6.9     9   26  2010    70
# 155         156  41.583333  145.000000  13.2     9   27  2010    77
# 156         157  14.000000  191.000000  14.3     9   28  2010    75
# 157         158  18.000000  131.000000   8.0     9   29  2010    76
#
#      Weather_C  Weather_PS  Weather_S
# 0            0           0          1
# 1            1           0          0
# ...

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
array = data_cleaned3.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:4])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.   0.24 0.56 0.3 ]
#  [0.01 0.21 0.34 0.33]
#  [0.01 0.07 0.43 0.57]
#  [0.02 0.1  0.94 0.52]
#  [0.03 0.24 0.55 0.66]]

# %%
from sklearn.preprocessing import StandardScaler
array = data_cleaned3.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,0:4])
# Out:
# [[-1.72e+00 -2.06e-02  5.32e-02 -7.31e-01]
#  [-1.70e+00 -1.97e-01 -7.80e-01 -5.59e-01]
#  [-1.68e+00 -1.04e+00 -4.21e-01  7.55e-01]
#  [-1.66e+00 -8.33e-01  1.48e+00  4.41e-01]
#  [-1.63e+00 -2.51e-16  0.00e+00  1.24e+00]]

# %%
# !pip install numpy==1.24
# !pip install sweetviz==2.2.1
# !pip install markupsafe
import sweetviz as sv
sweet_report = sv.analyze(df1)
sweet_report.show_html('weather_report.html')
# Out:
# ...
#                                              |          | [  0%]   00:00 -> (? left)
# Report weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 70.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=56889248e6bbd6842587a3c4b0fbd9b5d70a45e97faf3705c2119cd8c116c6b5
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.0
# ...

# %%
# !pip install typing-extensions --upgrade
from ydata_profiling import ProfileReport
# Out:
# ...
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
import pandas as pd
df1=pd.read_csv('data_clean.csv')
EDA_report=ProfileReport(df1)
EDA_report.to_file(output_file='report.html')
EDA_report
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-05-13 12:55:23.302834&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
